# %%
import pandas as pd
import numpy as np

# Reading and Checking data files
df = pd.read_csv(r"C:\Users\ASUS\Desktop\Codes\Python\train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
# Getting null columns and count of them
null_counts = df.isnull().sum()
if null_counts.any():
    print(null_counts[null_counts > 0])
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
# Dropping columns which contains so many missing values
df1 = df.drop(["Alley","MasVnrType","PoolQC","Fence","MiscFeature"],axis=1)

# %%
df1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
df1.shape
# Out:
# (1460, 76)

# %%
# Iterate over numeric columns only
for col in df1.select_dtypes(include=[np.number]).columns:
    if col != 'SalePrice':  # Exclude 'SalePrice' itself from comparison
        corr_value = df1['SalePrice'].corr(df1[col])
        print(f"The {col} corr is : {corr_value}")
# Out:
# The Id corr is : -0.021916719443431112
# The MSSubClass corr is : -0.08428413512659527
# The LotFrontage corr is : 0.3517990965706781
# The LotArea corr is : 0.2638433538714056
# The OverallQual corr is : 0.7909816005838051
# The OverallCond corr is : -0.07785589404867806
# The YearBuilt corr is : 0.522897332879497
# The YearRemodAdd corr is : 0.5071009671113863
# The MasVnrArea corr is : 0.47749304709571666
# The BsmtFinSF1 corr is : 0.38641980624215316
# The BsmtFinSF2 corr is : -0.011378121450215118
# The BsmtUnfSF corr is : 0.21447910554696897
# The TotalBsmtSF corr is : 0.6135805515591952
# The 1stFlrSF corr is : 0.6058521846919146
# The 2ndFlrSF corr is : 0.31933380283206814
# The LowQualFinSF corr is : -0.02560613000067956
# The GrLivArea corr is : 0.7086244776126521
# The BsmtFullBath corr is : 0.22712223313149374
# The BsmtHalfBath corr is : -0.016844154297359006
# The FullBath corr is : 0.5606637627484438
# The HalfBath corr is : 0.2841076755947834
# ...

# %%
# Dropping columns with low correlation
lower_bound = -0.5
upper_bound = 0.5

# Find columns whose correlation is between -0.5 and 0.5
cols_to_drop = []

for col in df1.select_dtypes(include=[np.number]).columns:
    if col != 'SalePrice':
        corr_value = df1['SalePrice'].corr(df1[col])
        if lower_bound < corr_value < upper_bound:
            cols_to_drop.append(col)
            print(f"Dropping {col} with correlation: {corr_value}")

# Create a new DataFrame by dropping the selected columns
df2 = df1.drop(cols_to_drop, axis=1)
# Out:
# Dropping Id with correlation: -0.021916719443431112
# Dropping MSSubClass with correlation: -0.08428413512659527
# Dropping LotFrontage with correlation: 0.3517990965706781
# Dropping LotArea with correlation: 0.2638433538714056
# Dropping OverallCond with correlation: -0.07785589404867806
# Dropping MasVnrArea with correlation: 0.47749304709571666
# Dropping BsmtFinSF1 with correlation: 0.38641980624215316
# Dropping BsmtFinSF2 with correlation: -0.011378121450215118
# Dropping BsmtUnfSF with correlation: 0.21447910554696897
# Dropping 2ndFlrSF with correlation: 0.31933380283206814
# Dropping LowQualFinSF with correlation: -0.02560613000067956
# Dropping BsmtFullBath with correlation: 0.22712223313149374
# Dropping BsmtHalfBath with correlation: -0.016844154297359006
# Dropping HalfBath with correlation: 0.2841076755947834
# Dropping BedroomAbvGr with correlation: 0.16821315430073985
# Dropping KitchenAbvGr with correlation: -0.13590737084214155
# ...

# %%
df2
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... GarageType GarageFinish  \
# ...

# %%
df2.shape
# Out:
# (1460, 49)

# %%
# Iterate over numeric columns only
for col in df2.select_dtypes(include=[np.number]).columns:
    if col != 'SalePrice':  # Exclude 'SalePrice' itself from comparison
        corr_value = df2['SalePrice'].corr(df2[col])
        print(f"The {col} corr is : {corr_value}")
# Out:
# The OverallQual corr is : 0.7909816005838051
# The YearBuilt corr is : 0.522897332879497
# The YearRemodAdd corr is : 0.5071009671113863
# The TotalBsmtSF corr is : 0.6135805515591952
# The 1stFlrSF corr is : 0.6058521846919146
# The GrLivArea corr is : 0.7086244776126521
# The FullBath corr is : 0.5606637627484438
# The TotRmsAbvGrd corr is : 0.5337231555820282
# The GarageCars corr is : 0.6404091972583519
# The GarageArea corr is : 0.6234314389183621

# %%
# Getting unique values of columns which has missing values
if null_counts.any():
    for col in df2.columns:
        if null_counts[col] > 0:
            unique_values = df2[col].unique()
            print(f"{col}: {unique_values}")
# Out:
# BsmtQual: ['Gd' 'TA' 'Ex' nan 'Fa']
# BsmtCond: ['TA' 'Gd' nan 'Fa' 'Po']
# BsmtExposure: ['No' 'Gd' 'Mn' 'Av' nan]
# BsmtFinType1: ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']
# BsmtFinType2: ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ']
# Electrical: ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]
# FireplaceQu: [nan 'TA' 'Gd' 'Fa' 'Ex' 'Po']
# GarageType: ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
# GarageFinish: ['RFn' 'Unf' 'Fin' nan]
# GarageQual: ['TA' 'Fa' 'Gd' nan 'Ex' 'Po']
# GarageCond: ['TA' 'Fa' nan 'Gd' 'Po' 'Ex']

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df2["BsmtQual"] = le.fit_transform(df2["BsmtQual"])

# Generate random values (2 or 3) for the missing values
random_values = np.random.choice([2, 3], size=df2['BsmtQual'].isna().sum())

# Create a mask for the missing values
missing_mask = df2['BsmtQual'].isna()

# Fill missing values in the 'BsmtQual' column with the random values
df2.loc[missing_mask, 'BsmtQual'] = random_values

plt.hist(df2["BsmtQual"])
# Out:
# (array([121.,   0.,  35.,   0.,   0., 618.,   0., 649.,   0.,  37.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
le = LabelEncoder()
df2["BsmtCond"] = le.fit_transform(df2["BsmtCond"])

# df2["BsmtCond"].fillna(3)

plt.hist(df2["BsmtCond"])
# Out:
# (array([  45.,    0.,   65.,    0.,    0.,    2.,    0., 1311.,    0.,
#           37.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
le = LabelEncoder()
df2["BsmtExposure"] = le.fit_transform(df2["BsmtExposure"])

df2["BsmtExposure"].fillna(3)

plt.hist(df2["BsmtExposure"])
# Out:
# (array([221.,   0., 134.,   0.,   0., 114.,   0., 953.,   0.,  38.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
le = LabelEncoder()
df2["BsmtFinType1"] = le.fit_transform(df2["BsmtFinType1"])

# Generate random values (0 to 6) for the missing values
random_values = np.random.choice([0, 6], size=df2['BsmtFinType1'].isna().sum())

# Create a mask for the missing values
missing_mask = df2['BsmtFinType1'].isna()

# Fill missing values in the 'BsmtQual' column with the random values
df2.loc[missing_mask, 'BsmtFinType1'] = random_values

plt.hist(df2["BsmtFinType1"])
# Out:
# (array([220., 148.,   0., 418.,   0.,  74., 133.,   0., 430.,  37.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
le = LabelEncoder()
df2["BsmtFinType2"] = le.fit_transform(df2["BsmtFinType2"])

df2["BsmtFinType2"].fillna(5)

plt.hist(df2["BsmtFinType2"])
# Out:
# (array([  19.,   33.,    0.,   14.,    0.,   46.,   54.,    0., 1256.,
#           38.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
le = LabelEncoder()
df2["Electrical"] = le.fit_transform(df2["Electrical"])

df['Electrical'].fillna(6)

plt.hist(df2["Electrical"])
# Out:
# (array([9.400e+01, 0.000e+00, 2.700e+01, 0.000e+00, 3.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 1.334e+03, 1.000e+00]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
le = LabelEncoder()
df2["FireplaceQu"] = le.fit_transform(df2["FireplaceQu"])

# Generate random values (2 or 3) for the missing values
random_values = np.random.choice([2, 3], size=df2['FireplaceQu'].isna().sum())

# Create a mask for the missing values
missing_mask = df2['FireplaceQu'].isna()

# Fill missing values in the 'FireplaceQu' column with the random values
df2.loc[missing_mask, 'FireplaceQu'] = random_values

plt.hist(df2["FireplaceQu"])
# Out:
# (array([ 24.,   0.,  33.,   0., 380.,   0.,  20.,   0., 313., 690.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
le = LabelEncoder()
df2["GarageType"] = le.fit_transform(df2["GarageType"])

# Generate random values (2 or 3) for the missing values
random_values = np.random.choice([2, 3], size=df2['GarageType'].isna().sum())

# Create a mask for the missing values
missing_mask = df2['GarageType'].isna()

# Fill missing values in the 'GarageType' column with the random values
df2.loc[missing_mask, 'GarageType'] = random_values

plt.hist(df2["GarageType"])
# Out:
# (array([  6., 870.,   0.,  19.,   0.,  88.,   9.,   0., 387.,  81.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
le = LabelEncoder()
df2["GarageFinish"] = le.fit_transform(df2["GarageFinish"])

# Generate random values (2 or 3) for the missing values
random_values = np.random.choice([0, 3], size=df2['GarageFinish'].isna().sum())

# Create a mask for the missing values
missing_mask = df2['GarageFinish'].isna()

# Fill missing values in the 'GarageFinish' column with the random values
df2.loc[missing_mask, 'GarageFinish'] = random_values

plt.hist(df2["GarageFinish"])
# Out:
# (array([352.,   0.,   0., 422.,   0.,   0., 605.,   0.,   0.,  81.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
le = LabelEncoder()
df2["GarageQual"] = le.fit_transform(df2["GarageQual"])

df2['GarageQual'].fillna(4)

plt.hist(df2["GarageQual"])
# Out:
# (array([   3.,    0.,   48.,    0.,   14.,    0.,    3.,    0., 1311.,
#           81.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
le = LabelEncoder()
df2["GarageCond"] = le.fit_transform(df2["GarageCond"])

df2['GarageCond'].fillna(4)

plt.hist(df2["GarageCond"])
# Out:
# (array([   2.,    0.,   35.,    0.,    9.,    0.,    7.,    0., 1326.,
#           81.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split 

# x = df2.drop(["SalePrice"],axis=1)
# y = df2["SalePrice"]

# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2024)
# model = LinearRegression().fit(x_train,y_train)
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... GarageType GarageFinish  \
# ...
